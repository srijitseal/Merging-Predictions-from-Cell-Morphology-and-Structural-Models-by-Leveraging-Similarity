# %%
#This notebook combines all metrics and heirarchial
import pandas as pd

# %%
all_preds_test_compounds_m= pd.read_csv("Predictions_train_heldout_scaled_prob_all_assays_ensemble_merger_test_compounds.csv")
all_preds_test_compounds_h= pd.read_csv("Predictions_train_heldout_scaled_prob_all_assays_heirarchial_model_test_compounds.csv")

# %%
metrics_list_m = pd.read_csv("All_metrics.csv")
metrics_list_h = pd.read_csv("heirarchial_model_metrics.csv")

# %%
all_preds_test_compounds = pd.merge(all_preds_test_compounds_m,all_preds_test_compounds_h)
all_preds_test_compounds= all_preds_test_compounds.sort_values("assay").reset_index(drop=True)
all_preds_test_compounds
# Out:
#          assay                             InChICode_standardised  fp_proba  \
# 0      178_684  InChI=1S/C24H28N4O4S/c1-14-12-28(15(2)13-29)24...  0.296817
# 1      178_684  InChI=1S/C22H36N4O4/c1-14(2)23-22(29)25(7)12-1...  0.054032
# 2      178_684  InChI=1S/C33H50N4O5/c1-23(2)34-33(40)35-28-15-...  0.176117
# 3      178_684  InChI=1S/C33H42N4O4S/c1-22-18-37(23(2)21-38)33...  0.483366
# 4      178_684  InChI=1S/C28H33ClN4O5S/c1-19-15-33(20(2)18-34)...  0.144869
# ...        ...                                                ...       ...
# 11727   93_259  InChI=1S/C16H20N2/c1-18(2)13-11-15(14-8-4-3-5-...  0.154095
# 11728   93_259  InChI=1S/C7H6O3/c8-6-4-2-1-3-5(6)7(9)10/h1-4,8...  0.262474
# 11729   93_259  InChI=1S/C16H13N3O3/c1-22-16(21)19-15-17-12-8-...  0.334415
# 11730   93_259  InChI=1S/C12H15N3OS/c1-9-2-4-10(5-3-9)15-11(16...  0.277662
# 11731   93_259  InChI=1S/C12H16N2O/c1-10-3-5-11(6-4-10)9-14-8-...  0.302401
#
#        fp_pred  fp_threshold  CP_proba  CP_pred  CP_threshold  true        ts  \
# 0            0      0.325363  0.706426        1      0.240378   1.0  0.661017
# 1            0      0.325363  0.223650        0      0.240378   0.0  0.875000
# 2            0      0.325363  0.189580        0      0.240378   0.0  0.746988
# 3            1      0.325363  0.197281        0      0.240378   0.0  0.696970
# 4            0      0.325363  0.079811        0      0.240378   0.0  0.720000
# ...        ...           ...       ...      ...           ...   ...       ...
# 11727        0      0.240921  0.115982        0      0.260921   0.0  0.363636
# 11728        1      0.240921  0.164087        0      0.260921   0.0  0.388889
# 11729        1      0.240921  0.371684        1      0.260921   0.0  0.344828
# 11730        1      0.240921  0.213211        0      0.260921   0.0  0.307692
# 11731        1      0.240921  0.257346        0      0.260921   0.0  0.312500
#
#        ...  MFP_Correct CP_Correct  fp_proba_scaled  CP_proba_scaled  \
# 0      ...        False       True         0.456133         0.806763
# 1      ...         True       True         0.083034         0.465206
# 2      ...         True       True         0.270646         0.394338
# 3      ...        False       True         0.617102         0.410356
# 4      ...         True       True         0.222627         0.166011
# ...    ...          ...        ...              ...              ...
# 11727  ...         True       True         0.319804         0.222255
# 11728  ...        False       True         0.514197         0.314438
# 11729  ...        False      False         0.561583         0.574934
# 11730  ...        False       True         0.524201         0.408575
# 11731  ...        False       True         0.540496         0.493151
#
#        simple_pred  Ensemble_Correct  merger_pred  merger_Correct  \
# 0              1.0              True          1.0            True
# 1              0.0              True          0.0            True
# 2              0.0              True          0.0            True
# 3              1.0             False          1.0           False
# 4              0.0              True          0.0            True
# ...            ...               ...          ...             ...
# 11727          0.0              True          0.0            True
# 11728          0.0              True          0.0            True
# 11729          1.0             False          0.0            True
# 11730          0.0              True          0.0            True
# 11731          1.0             False          0.0            True
#
#        heirarchial_pred  heirarchial_Correct
# 0                   1.0                 True
# 1                   0.0                 True
# 2                   0.0                 True
# 3                   1.0                False
# 4                   0.0                 True
# ...                 ...                  ...
# 11727               0.0                 True
# 11728               0.0                 True
# 11729               1.0                False
# 11730               1.0                False
# 11731               1.0                False
#
# [11732 rows x 22 columns]

# %%
metrics_list_m
# Out:
#        assay                 method        f1  precision  Sensitivity  \
# 0    178_684                     CP  0.606061   0.526316     0.714286
# 1    178_684                    MFP  0.434783   0.555556     0.357143
# 2    178_684      Ensemble Averaged  0.583333   0.700000     0.500000
# 3    178_684  Distance Based Merger  0.727273   0.631579     0.857143
# 4    180_686                     CP  0.588235   0.714286     0.500000
# ..       ...                    ...       ...        ...          ...
# 351  283_762  Distance Based Merger  0.571429   0.408163     0.952381
# 352   93_259                     CP  0.470588   0.400000     0.571429
# 353   93_259                    MFP  0.370370   0.250000     0.714286
# 354   93_259      Ensemble Averaged  0.444444   0.363636     0.571429
# 355   93_259  Distance Based Merger  0.400000   0.666667     0.285714
#
#      Specificity        ba       mcc       AUC
# 0       0.780488  0.747387  0.453246  0.754355
# 1       0.902439  0.629791  0.305654  0.771777
# 2       0.926829  0.713415  0.482063  0.713415
# 3       0.829268  0.843206  0.628800  0.872822
# 4       0.935484  0.717742  0.497009  0.777419
# ..           ...       ...       ...       ...
# 351     0.553846  0.753114  0.439251  0.734066
# 352     0.684211  0.627820  0.233074  0.578947
# 353     0.210526  0.462406 -0.079156  0.586466
# 354     0.631579  0.601504  0.182262  0.601504
# 355     0.947368  0.616541  0.323602  0.699248
#
# [356 rows x 9 columns]

# %%
metrics_list_h
# Out:
#       assay             method        f1  precision  Sensitivity  Specificity  \
# 0   178_684  Heirarchial Model  0.620690   0.600000     0.642857     0.853659
# 1   180_686  Heirarchial Model  0.516129   0.380952     0.800000     0.580645
# 2   183_604  Heirarchial Model  0.418605   0.264706     1.000000     0.074074
# 3   184_606  Heirarchial Model  0.700000   0.583333     0.875000     0.787234
# 4   185_665  Heirarchial Model  0.352941   0.272727     0.500000     0.555556
# ..      ...                ...       ...        ...          ...          ...
# 84  278_757  Heirarchial Model  0.544643   0.409396     0.813333     0.612335
# 85  279_758  Heirarchial Model  0.478261   0.333333     0.846154     0.450000
# 86  280_759  Heirarchial Model  0.733333   0.666667     0.814815     0.864198
# 87  283_762  Heirarchial Model  0.250000   0.169492     0.476190     0.246154
# 88   93_259  Heirarchial Model  0.400000   0.277778     0.714286     0.315789
#
#           ba       mcc       AUC
# 0   0.748258  0.485639  0.789199
# 1   0.690323  0.327022  0.716129
# 2   0.537037  0.140028  0.720165
# 3   0.831117  0.593584  0.921543
# 4   0.527778  0.048280  0.564815
# ..       ...       ...       ...
# 84  0.712834  0.367854  0.802584
# 85  0.648077  0.262874  0.815385
# 86  0.839506  0.638285  0.942844
# 87  0.361172 -0.257019  0.358242
# 88  0.515038  0.028904  0.586466
#
# [89 rows x 9 columns]

# %%
metrics_list = pd.concat([metrics_list_m,metrics_list_h])
metrics_list = metrics_list.sort_values(["assay", "method"]).reset_index(drop=True)
metrics_list
# Out:
#        assay                 method        f1  precision  Sensitivity  \
# 0    178_684                     CP  0.606061   0.526316     0.714286
# 1    178_684  Distance Based Merger  0.727273   0.631579     0.857143
# 2    178_684      Ensemble Averaged  0.583333   0.700000     0.500000
# 3    178_684      Heirarchial Model  0.620690   0.600000     0.642857
# 4    178_684                    MFP  0.434783   0.555556     0.357143
# ..       ...                    ...       ...        ...          ...
# 440   93_259                     CP  0.470588   0.400000     0.571429
# 441   93_259  Distance Based Merger  0.400000   0.666667     0.285714
# 442   93_259      Ensemble Averaged  0.444444   0.363636     0.571429
# 443   93_259      Heirarchial Model  0.400000   0.277778     0.714286
# 444   93_259                    MFP  0.370370   0.250000     0.714286
#
#      Specificity        ba       mcc       AUC
# 0       0.780488  0.747387  0.453246  0.754355
# 1       0.829268  0.843206  0.628800  0.872822
# 2       0.926829  0.713415  0.482063  0.713415
# 3       0.853659  0.748258  0.485639  0.789199
# 4       0.902439  0.629791  0.305654  0.771777
# ..           ...       ...       ...       ...
# 440     0.684211  0.627820  0.233074  0.578947
# 441     0.947368  0.616541  0.323602  0.699248
# 442     0.631579  0.601504  0.182262  0.601504
# 443     0.315789  0.515038  0.028904  0.586466
# 444     0.210526  0.462406 -0.079156  0.586466
#
# [445 rows x 9 columns]

# %%
metrics_list.to_csv("All_metrics_merger_heirarchial.csv", index=False)

# %%
all_preds_test_compounds.to_csv("Predictions_train_heldout_scaled_prob_all_assays_ensemble_merger_heirarchial_test_compounds.csv", index=False)
