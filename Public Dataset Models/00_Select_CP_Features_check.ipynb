# %%
#
# blacklist
# variance_threshold
# correlation_threshold
# drop_outliers
#

# %%
blacklist=["Nuclei_Correlation_Manders_AGP_DNA",
            "Nuclei_Correlation_Manders_AGP_ER",
            "Nuclei_Correlation_Manders_AGP_Mito",
            "Nuclei_Correlation_Manders_AGP_RNA",
            "Nuclei_Correlation_Manders_DNA_AGP",
            "Nuclei_Correlation_Manders_DNA_ER",
            "Nuclei_Correlation_Manders_DNA_Mito",
            "Nuclei_Correlation_Manders_DNA_RNA",
            "Nuclei_Correlation_Manders_ER_AGP",
            "Nuclei_Correlation_Manders_ER_DNA",
            "Nuclei_Correlation_Manders_ER_Mito",
            "Nuclei_Correlation_Manders_ER_RNA",
            "Nuclei_Correlation_Manders_Mito_AGP",
            "Nuclei_Correlation_Manders_Mito_DNA",
            "Nuclei_Correlation_Manders_Mito_ER",
            "Nuclei_Correlation_Manders_Mito_RNA",
            "Nuclei_Correlation_Manders_RNA_AGP",
            "Nuclei_Correlation_Manders_RNA_DNA",
            "Nuclei_Correlation_Manders_RNA_ER",
            "Nuclei_Correlation_Manders_RNA_Mito",
            "Nuclei_Correlation_RWC_AGP_DNA",
            "Nuclei_Correlation_RWC_AGP_ER",
            "Nuclei_Correlation_RWC_AGP_Mito",
            "Nuclei_Correlation_RWC_AGP_RNA",
            "Nuclei_Correlation_RWC_DNA_AGP",
            "Nuclei_Correlation_RWC_DNA_ER",
            "Nuclei_Correlation_RWC_DNA_Mito",
            "Nuclei_Correlation_RWC_DNA_RNA",
            "Nuclei_Correlation_RWC_ER_AGP",
            "Nuclei_Correlation_RWC_ER_DNA",
            "Nuclei_Correlation_RWC_ER_Mito",
            "Nuclei_Correlation_RWC_ER_RNA",
            "Nuclei_Correlation_RWC_Mito_AGP",
            "Nuclei_Correlation_RWC_Mito_DNA",
            "Nuclei_Correlation_RWC_Mito_ER",
            "Nuclei_Correlation_RWC_Mito_RNA",
            "Nuclei_Correlation_RWC_RNA_AGP",
            "Nuclei_Correlation_RWC_RNA_DNA",
            "Nuclei_Correlation_RWC_RNA_ER",
            "Nuclei_Correlation_RWC_RNA_Mito",
            "Nuclei_Granularity_14_AGP",
            "Nuclei_Granularity_14_DNA",
            "Nuclei_Granularity_14_ER",
            "Nuclei_Granularity_14_Mito",
            "Nuclei_Granularity_14_RNA",
            "Nuclei_Granularity_15_AGP",
            "Nuclei_Granularity_15_DNA",
            "Nuclei_Granularity_15_ER",
            "Nuclei_Granularity_15_Mito",
            "Nuclei_Granularity_15_RNA",
            "Nuclei_Granularity_16_AGP",
            "Nuclei_Granularity_16_DNA",
            "Nuclei_Granularity_16_ER",
            "Nuclei_Granularity_16_Mito",
            "Nuclei_Granularity_16_RNA"]

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#blacklist features are already removed

# %%
pubchem_data = pd.read_csv("Pubchem_92_assays_binary.csv", usecols=lambda x: x not in blacklist)

# %%
CP_features_list= pubchem_data.columns.to_list()[94:-3]
assay_list= pubchem_data.columns.to_list()[1:93]

# %%
CP_pubchem_data = pubchem_data[CP_features_list] 
CP_pubchem_data["StdInChI"] = pubchem_data["StdInChI"]
CP_pubchem_data
# Out:
# /home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#        Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# 0                164.781250                 10.234375
# 1                103.429688                  4.937500
# 2                136.343750                 -1.464844
# 3                427.921875                  2.648438
# 4                127.636719                  6.675781
# ...                     ...                       ...
# 10397           -346.476562                 20.183594
# 10398            100.273438                  6.718750
# 10399            -86.156250                  2.718750
# 10400            656.109375                 11.808594
# 10401            -61.890625                 10.984375
#
#        Cells_AreaShape_Center_Y  Cells_AreaShape_Compactness  \
# 0                      6.187500                     0.017088
# 1                     -2.382812                     0.004397
# 2                     -2.585938                     0.007923
# 3                     -3.335938                     0.013197
# 4                     -7.687500                     0.041599
# ...                         ...                          ...
# 10397                 -4.066406                     0.008341
# 10398                  1.433594                     0.015161
# 10399                 -1.097656                    -0.003625
# 10400                  4.699219                    -0.038869
# 10401                  0.980469                    -0.013988
#
#        Cells_AreaShape_Eccentricity  Cells_AreaShape_EulerNumber  \
# 0                          0.016307                          0.0
# 1                          0.010849                          0.0
# 2                          0.005463                          0.0
# 3                          0.010676                          0.0
# 4                          0.023155                          0.0
# ...                             ...                          ...
# 10397                      0.008142                          0.0
# 10398                      0.010760                          0.0
# 10399                     -0.007101                          0.0
# 10400                     -0.020235                          0.0
# 10401                     -0.003641                          0.0
#
#        Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                   -0.003710                    0.014207
# 1                    0.002559                   -0.001142
# 2                   -0.002972                    0.003458
# 3                   -0.000601                    0.005521
# 4                   -0.011129                    0.005713
# ...                       ...                         ...
# 10397               -0.001581                    0.008370
# 10398               -0.008705                    0.028187
# 10399               -0.003697                   -0.001145
# 10400                0.034422                    0.033860
# 10401                0.004654                    0.015252
#
#        Cells_AreaShape_MajorAxisLength  Cells_AreaShape_MaxFeretDiameter  ...  \
# 0                             5.037665                          5.035500  ...
# 1                             2.952237                          2.770976  ...
# 2                             1.594667                          1.505522  ...
# 3                             6.815850                          6.662820  ...
# 4                             5.245950                          4.780417  ...
# ...                                ...                               ...  ...
# 10397                        -4.779200                         -5.112849  ...
# 10398                         2.185087                          2.375410  ...
# 10399                        -1.827360                         -2.115774  ...
# 10400                         5.466021                          5.977704  ...
# 10401                        -1.698557                         -1.521501  ...
#
#        Nuclei_Texture_Variance_DNA_3_0  Nuclei_Texture_Variance_DNA_5_0  \
# 0                            -0.042734                        -0.045724
# 1                            -0.073700                        -0.067454
# 2                             0.199427                         0.217519
# 3                            -0.172205                        -0.154801
# 4                            -0.104033                        -0.081204
# ...                                ...                              ...
# 10397                         0.068750                         0.054730
# 10398                        -0.013937                        -0.013465
# 10399                        -0.147879                        -0.153633
# 10400                        -0.052092                        -0.033957
# 10401                         0.049478                         0.063903
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_3_0  \
# 0                            -0.064442                       -0.083984
# 1                            -0.029972                       -0.059979
# 2                             0.020276                        0.022685
# 3                            -0.108891                       -0.148361
# 4                             0.013632                       -0.001829
# ...                                ...                             ...
# 10397                         0.077785                        0.053886
# 10398                        -0.040793                       -0.023397
# 10399                         0.003183                       -0.024677
# 10400                         0.463339                        0.546176
# 10401                         0.167289                        0.101842
#
#        Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                           -0.085743                          -0.049853
# 1                           -0.052889                           0.017667
# 2                            0.032980                          -0.050662
# 3                           -0.149801                          -0.022526
# 4                            0.022562                          -0.157595
# ...                               ...                                ...
# 10397                        0.053411                          -0.046787
# 10398                       -0.046764                          -0.123188
# 10399                       -0.016327                          -0.033117
# 10400                        0.530553                           0.091231
# 10401                        0.140921                           0.021183
#
#        Nuclei_Texture_Variance_Mito_3_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                             -0.049552                         -0.053859
# 1                             -0.004665                          0.006729
# 2                             -0.021212                         -0.020383
# 3                             -0.021288                         -0.024947
# 4                             -0.117522                         -0.119432
# ...                                 ...                               ...
# 10397                         -0.101272                         -0.089872
# 10398                         -0.146195                         -0.156000
# 10399                         -0.051361                         -0.044799
# 10400                          0.031603                          0.085972
# 10401                         -0.006542                         -0.008197
#
#        Nuclei_Texture_Variance_RNA_10_0  \
# 0                             -0.037229
# 1                              0.070510
# 2                             -0.056293
# 3                             -0.030227
# 4                              0.010668
# ...                                 ...
# 10397                         -0.064416
# 10398                          0.009448
# 10399                         -0.020764
# 10400                         -0.263527
# 10401                          0.011932
#
#                                                 StdInChI
# 0      InChI=1S/C11H14ClN3O4S3/c1-2-3-20-6-11-14-8-4-...
# 1      InChI=1S/C25H27ClN2O/c26-22-12-7-13-23(18-22)2...
# 2      InChI=1S/C18H20O2/c1-18-9-8-14-13-5-3-12(19)10...
# 3      InChI=1S/C16H13ClN2O/c1-19-14-8-7-12(17)9-13(1...
# 4      InChI=1S/C10H14ClN3/c11-9-2-1-3-10(13-9)14-6-4...
# ...                                                  ...
# 10397  InChI=1S/C34H41N5O3S/c1-34(2,3)43(42)39-23-28-...
# 10398  InChI=1S/C34H36N4O3S/c1-34(2,3)42(41)38-22-28-...
# 10399  InChI=1S/C33H39N5O3S/c1-33(2,3)42(41)38-22-27-...
# 10400  InChI=1S/C27H26ClFN2O6S/c28-17-3-1-16(2-4-17)1...
# 10401  InChI=1S/C26H31N3O7/c1-29(2)12-25(32)28-16-4-6...
#
# [10402 rows x 1727 columns]

# %%
#CP_pubchem_data.to_csv("CP_all_features_10402.csv", index=False)

# %%
from sklearn.feature_selection import VarianceThreshold
from itertools import compress

def fs_variance(df, threshold:float=0.05):
    """
    Return a list of selected variables based on the threshold.
    """

    # The list of columns in the data frame
    features = list(df.columns)
    
    # Initialize and fit the method
    vt = VarianceThreshold(threshold = threshold)
    _ = vt.fit(df)
    
    # Get which column names which pass the threshold
    feat_select = list(compress(features, vt.get_support()))
    
    return feat_select

selected_Features = fs_variance(CP_pubchem_data.iloc[:,:-1], threshold=0.005)
len(selected_Features)
# Out:
# 715

# %%
new_CP_pubchem_data= CP_pubchem_data[selected_Features]
new_CP_pubchem_data
# Out:
#        Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# 0                164.781250                 10.234375
# 1                103.429688                  4.937500
# 2                136.343750                 -1.464844
# 3                427.921875                  2.648438
# 4                127.636719                  6.675781
# ...                     ...                       ...
# 10397           -346.476562                 20.183594
# 10398            100.273438                  6.718750
# 10399            -86.156250                  2.718750
# 10400            656.109375                 11.808594
# 10401            -61.890625                 10.984375
#
#        Cells_AreaShape_Center_Y  Cells_AreaShape_MajorAxisLength  \
# 0                      6.187500                         5.037665
# 1                     -2.382812                         2.952237
# 2                     -2.585938                         1.594667
# 3                     -3.335938                         6.815850
# 4                     -7.687500                         5.245950
# ...                         ...                              ...
# 10397                 -4.066406                        -4.779200
# 10398                  1.433594                         2.185087
# 10399                 -1.097656                        -1.827360
# 10400                  4.699219                         5.466021
# 10401                  0.980469                        -1.698557
#
#        Cells_AreaShape_MaxFeretDiameter  Cells_AreaShape_MaximumRadius  \
# 0                              5.035500                       0.439456
# 1                              2.770976                       0.298226
# 2                              1.505522                       0.175149
# 3                              6.662820                       1.380349
# 4                              4.780417                       0.226874
# ...                                 ...                            ...
# 10397                         -5.112849                      -1.276011
# 10398                          2.375410                       0.281030
# 10399                         -2.115774                      -0.156995
# 10400                          5.977704                       3.240073
# 10401                         -1.521501                      -0.110540
#
#        Cells_AreaShape_MeanRadius  Cells_AreaShape_MedianRadius  \
# 0                        0.130310                      0.227574
# 1                        0.128853                      0.096478
# 2                        0.067577                      0.028387
# 3                        0.585265                      0.501840
# 4                        0.215360                      0.203040
# ...                           ...                           ...
# 10397                   -0.495676                     -0.453494
# 10398                    0.106338                      0.203923
# 10399                   -0.087056                     -0.047562
# 10400                    1.128961                      0.911463
# 10401                   -0.013907                      0.015294
#
#        Cells_AreaShape_MinFeretDiameter  Cells_AreaShape_MinorAxisLength  ...  \
# 0                              1.292714                         0.656864  ...
# 1                              1.044871                         0.139059  ...
# 2                              0.677448                         0.619944  ...
# 3                              3.324920                         2.906994  ...
# 4                              0.537290                         0.466345  ...
# ...                                 ...                              ...  ...
# 10397                         -3.224767                        -2.680170  ...
# 10398                          0.714687                         0.661985  ...
# 10399                          0.586760                         0.585998  ...
# 10400                          5.843655                         7.285258  ...
# 10401                         -0.997024                        -0.820761  ...
#
#        Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_3_0  \
# 0                             -0.010652                        -0.042734
# 1                             -0.083660                        -0.073700
# 2                              0.234284                         0.199427
# 3                             -0.102389                        -0.172205
# 4                             -0.108354                        -0.104033
# ...                                 ...                              ...
# 10397                          0.016347                         0.068750
# 10398                          0.021250                        -0.013937
# 10399                         -0.116773                        -0.147879
# 10400                         -0.135876                        -0.052092
# 10401                          0.070383                         0.049478
#
#        Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                            -0.045724                        -0.064442
# 1                            -0.067454                        -0.029972
# 2                             0.217519                         0.020276
# 3                            -0.154801                        -0.108891
# 4                            -0.081204                         0.013632
# ...                                ...                              ...
# 10397                         0.054730                         0.077785
# 10398                        -0.013465                        -0.040793
# 10399                        -0.153633                         0.003183
# 10400                        -0.033957                         0.463339
# 10401                         0.063903                         0.167289
#
#        Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                           -0.083984                       -0.085743
# 1                           -0.059979                       -0.052889
# 2                            0.022685                        0.032980
# 3                           -0.148361                       -0.149801
# 4                           -0.001829                        0.022562
# ...                               ...                             ...
# 10397                        0.053886                        0.053411
# 10398                       -0.023397                       -0.046764
# 10399                       -0.024677                       -0.016327
# 10400                        0.546176                        0.530553
# 10401                        0.101842                        0.140921
#
#        Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                              -0.049853                         -0.049552
# 1                               0.017667                         -0.004665
# 2                              -0.050662                         -0.021212
# 3                              -0.022526                         -0.021288
# 4                              -0.157595                         -0.117522
# ...                                  ...                               ...
# 10397                          -0.046787                         -0.101272
# 10398                          -0.123188                         -0.146195
# 10399                          -0.033117                         -0.051361
# 10400                           0.091231                          0.031603
# 10401                           0.021183                         -0.006542
#
#        Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0
# 0                             -0.053859                         -0.037229
# 1                              0.006729                          0.070510
# 2                             -0.020383                         -0.056293
# 3                             -0.024947                         -0.030227
# 4                             -0.119432                          0.010668
# ...                                 ...                               ...
# 10397                         -0.089872                         -0.064416
# 10398                         -0.156000                          0.009448
# 10399                         -0.044799                         -0.020764
# 10400                          0.085972                         -0.263527
# 10401                         -0.008197                          0.011932
#
# [10402 rows x 715 columns]

# %%
def get_pairwise_correlation(population_df, method="pearson"):
    """Given a population dataframe, calculate all pairwise correlations.
    Parameters
    ----------
    population_df : pandas.core.frame.DataFrame
        Includes metadata and observation features.
    method : str, default "pearson"
        Which correlation matrix to use to test cutoff.
    Returns
    -------
    list of str
        Features to exclude from the population_df.
    """


    # Get a symmetrical correlation matrix
    data_cor_df = population_df.corr(method=method)

    # Create a copy of the dataframe to generate upper triangle of zeros
    data_cor_natri_df = data_cor_df.copy()

    # Replace upper triangle in correlation matrix with NaN
    data_cor_natri_df = data_cor_natri_df.where(
        np.tril(np.ones(data_cor_natri_df.shape), k=-1).astype(np.bool)
    )

    # Acquire pairwise correlations in a long format
    # Note that we are using the NaN upper triangle DataFrame
    pairwise_df = data_cor_natri_df.stack().reset_index()
    pairwise_df.columns = ["pair_a", "pair_b", "correlation"]

    return data_cor_df, pairwise_df

# %%
# Get correlation matrix and lower triangle of pairwise correlations in long format
data_cor_df, pairwise_df = get_pairwise_correlation(population_df=new_CP_pubchem_data)
# Out:
# /tmp/ipykernel_26115/3078888421.py:24: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.tril(np.ones(data_cor_natri_df.shape), k=-1).astype(np.bool)

# %%
data_cor_df
# Out:
#                                    Cells_AreaShape_Area  \
# Cells_AreaShape_Area                           1.000000
# Cells_AreaShape_Center_X                      -0.098339
# Cells_AreaShape_Center_Y                      -0.030454
# Cells_AreaShape_MajorAxisLength                0.940841
# Cells_AreaShape_MaxFeretDiameter               0.942927
# ...                                                 ...
# Nuclei_Texture_Variance_ER_5_0                -0.410450
# Nuclei_Texture_Variance_Mito_10_0             -0.402776
# Nuclei_Texture_Variance_Mito_3_0              -0.466908
# Nuclei_Texture_Variance_Mito_5_0              -0.465243
# Nuclei_Texture_Variance_RNA_10_0              -0.190705
#
#                                    Cells_AreaShape_Center_X  \
# Cells_AreaShape_Area                              -0.098339
# Cells_AreaShape_Center_X                           1.000000
# Cells_AreaShape_Center_Y                           0.006942
# Cells_AreaShape_MajorAxisLength                   -0.113692
# Cells_AreaShape_MaxFeretDiameter                  -0.114167
# ...                                                     ...
# Nuclei_Texture_Variance_ER_5_0                     0.220046
# Nuclei_Texture_Variance_Mito_10_0                  0.180561
# Nuclei_Texture_Variance_Mito_3_0                   0.203888
# Nuclei_Texture_Variance_Mito_5_0                   0.203251
# Nuclei_Texture_Variance_RNA_10_0                   0.083418
#
#                                    Cells_AreaShape_Center_Y  \
# Cells_AreaShape_Area                              -0.030454
# Cells_AreaShape_Center_X                           0.006942
# Cells_AreaShape_Center_Y                           1.000000
# Cells_AreaShape_MajorAxisLength                   -0.014232
# Cells_AreaShape_MaxFeretDiameter                  -0.015185
# ...                                                     ...
# Nuclei_Texture_Variance_ER_5_0                    -0.049593
# Nuclei_Texture_Variance_Mito_10_0                 -0.044146
# Nuclei_Texture_Variance_Mito_3_0                  -0.027690
# Nuclei_Texture_Variance_Mito_5_0                  -0.022484
# Nuclei_Texture_Variance_RNA_10_0                  -0.075793
#
#                                    Cells_AreaShape_MajorAxisLength  \
# Cells_AreaShape_Area                                      0.940841
# Cells_AreaShape_Center_X                                 -0.113692
# Cells_AreaShape_Center_Y                                 -0.014232
# Cells_AreaShape_MajorAxisLength                           1.000000
# Cells_AreaShape_MaxFeretDiameter                          0.995077
# ...                                                            ...
# Nuclei_Texture_Variance_ER_5_0                           -0.493739
# Nuclei_Texture_Variance_Mito_10_0                        -0.509588
# Nuclei_Texture_Variance_Mito_3_0                         -0.577228
# Nuclei_Texture_Variance_Mito_5_0                         -0.574887
# Nuclei_Texture_Variance_RNA_10_0                         -0.255735
#
#                                    Cells_AreaShape_MaxFeretDiameter  \
# Cells_AreaShape_Area                                       0.942927
# Cells_AreaShape_Center_X                                  -0.114167
# Cells_AreaShape_Center_Y                                  -0.015185
# Cells_AreaShape_MajorAxisLength                            0.995077
# Cells_AreaShape_MaxFeretDiameter                           1.000000
# ...                                                             ...
# Nuclei_Texture_Variance_ER_5_0                            -0.507519
# Nuclei_Texture_Variance_Mito_10_0                         -0.518317
# Nuclei_Texture_Variance_Mito_3_0                          -0.585288
# Nuclei_Texture_Variance_Mito_5_0                          -0.583702
# Nuclei_Texture_Variance_RNA_10_0                          -0.261028
#
#                                    Cells_AreaShape_MaximumRadius  \
# Cells_AreaShape_Area                                    0.939260
# Cells_AreaShape_Center_X                               -0.085548
# Cells_AreaShape_Center_Y                               -0.036490
# Cells_AreaShape_MajorAxisLength                         0.825168
# Cells_AreaShape_MaxFeretDiameter                        0.829064
# ...                                                          ...
# Nuclei_Texture_Variance_ER_5_0                         -0.362873
# Nuclei_Texture_Variance_Mito_10_0                      -0.326947
# Nuclei_Texture_Variance_Mito_3_0                       -0.392954
# Nuclei_Texture_Variance_Mito_5_0                       -0.397751
# Nuclei_Texture_Variance_RNA_10_0                       -0.151187
#
#                                    Cells_AreaShape_MeanRadius  \
# Cells_AreaShape_Area                                 0.927703
# Cells_AreaShape_Center_X                            -0.083790
# Cells_AreaShape_Center_Y                            -0.040336
# Cells_AreaShape_MajorAxisLength                      0.813784
# Cells_AreaShape_MaxFeretDiameter                     0.814888
# ...                                                       ...
# Nuclei_Texture_Variance_ER_5_0                      -0.350666
# Nuclei_Texture_Variance_Mito_10_0                   -0.309373
# Nuclei_Texture_Variance_Mito_3_0                    -0.378869
# Nuclei_Texture_Variance_Mito_5_0                    -0.384016
# Nuclei_Texture_Variance_RNA_10_0                    -0.140025
#
#                                    Cells_AreaShape_MedianRadius  \
# Cells_AreaShape_Area                                   0.914388
# Cells_AreaShape_Center_X                              -0.080652
# Cells_AreaShape_Center_Y                              -0.041165
# Cells_AreaShape_MajorAxisLength                        0.805505
# Cells_AreaShape_MaxFeretDiameter                       0.805093
# ...                                                         ...
# Nuclei_Texture_Variance_ER_5_0                        -0.338483
# Nuclei_Texture_Variance_Mito_10_0                     -0.300783
# Nuclei_Texture_Variance_Mito_3_0                      -0.370342
# Nuclei_Texture_Variance_Mito_5_0                      -0.375450
# Nuclei_Texture_Variance_RNA_10_0                      -0.137165
#
#                                    Cells_AreaShape_MinFeretDiameter  \
# Cells_AreaShape_Area                                       0.955868
# Cells_AreaShape_Center_X                                  -0.114143
# Cells_AreaShape_Center_Y                                  -0.024092
# Cells_AreaShape_MajorAxisLength                            0.875455
# Cells_AreaShape_MaxFeretDiameter                           0.883737
# ...                                                             ...
# Nuclei_Texture_Variance_ER_5_0                            -0.470079
# Nuclei_Texture_Variance_Mito_10_0                         -0.437763
# Nuclei_Texture_Variance_Mito_3_0                          -0.508099
# Nuclei_Texture_Variance_Mito_5_0                          -0.510996
# Nuclei_Texture_Variance_RNA_10_0                          -0.213382
#
#                                    Cells_AreaShape_MinorAxisLength  ...  \
# Cells_AreaShape_Area                                      0.939500  ...
# Cells_AreaShape_Center_X                                 -0.101915  ...
# Cells_AreaShape_Center_Y                                 -0.027880  ...
# Cells_AreaShape_MajorAxisLength                           0.832828  ...
# Cells_AreaShape_MaxFeretDiameter                          0.840066  ...
# ...                                                            ...  ...
# Nuclei_Texture_Variance_ER_5_0                           -0.420276  ...
# Nuclei_Texture_Variance_Mito_10_0                        -0.385627  ...
# Nuclei_Texture_Variance_Mito_3_0                         -0.453750  ...
# Nuclei_Texture_Variance_Mito_5_0                         -0.457676  ...
# Nuclei_Texture_Variance_RNA_10_0                         -0.192799  ...
#
#                                    Nuclei_Texture_Variance_DNA_10_0  \
# Cells_AreaShape_Area                                      -0.347895
# Cells_AreaShape_Center_X                                   0.079514
# Cells_AreaShape_Center_Y                                  -0.038902
# Cells_AreaShape_MajorAxisLength                           -0.373929
# Cells_AreaShape_MaxFeretDiameter                          -0.386536
# ...                                                             ...
# Nuclei_Texture_Variance_ER_5_0                             0.486442
# Nuclei_Texture_Variance_Mito_10_0                          0.430464
# Nuclei_Texture_Variance_Mito_3_0                           0.420387
# Nuclei_Texture_Variance_Mito_5_0                           0.413942
# Nuclei_Texture_Variance_RNA_10_0                           0.600167
#
#                                    Nuclei_Texture_Variance_DNA_3_0  \
# Cells_AreaShape_Area                                     -0.400779
# Cells_AreaShape_Center_X                                  0.121188
# Cells_AreaShape_Center_Y                                 -0.046702
# Cells_AreaShape_MajorAxisLength                          -0.450789
# Cells_AreaShape_MaxFeretDiameter                         -0.464704
# ...                                                            ...
# Nuclei_Texture_Variance_ER_5_0                            0.642509
# Nuclei_Texture_Variance_Mito_10_0                         0.497779
# Nuclei_Texture_Variance_Mito_3_0                          0.565840
# Nuclei_Texture_Variance_Mito_5_0                          0.557893
# Nuclei_Texture_Variance_RNA_10_0                          0.571874
#
#                                    Nuclei_Texture_Variance_DNA_5_0  \
# Cells_AreaShape_Area                                     -0.423878
# Cells_AreaShape_Center_X                                  0.125062
# Cells_AreaShape_Center_Y                                 -0.046489
# Cells_AreaShape_MajorAxisLength                          -0.471919
# Cells_AreaShape_MaxFeretDiameter                         -0.485887
# ...                                                            ...
# Nuclei_Texture_Variance_ER_5_0                            0.650405
# Nuclei_Texture_Variance_Mito_10_0                         0.508536
# Nuclei_Texture_Variance_Mito_3_0                          0.579229
# Nuclei_Texture_Variance_Mito_5_0                          0.572721
# Nuclei_Texture_Variance_RNA_10_0                          0.574267
#
#                                    Nuclei_Texture_Variance_ER_10_0  \
# Cells_AreaShape_Area                                     -0.333348
# Cells_AreaShape_Center_X                                  0.206647
# Cells_AreaShape_Center_Y                                 -0.058047
# Cells_AreaShape_MajorAxisLength                          -0.407735
# Cells_AreaShape_MaxFeretDiameter                         -0.421252
# ...                                                            ...
# Nuclei_Texture_Variance_ER_5_0                            0.922814
# Nuclei_Texture_Variance_Mito_10_0                         0.650643
# Nuclei_Texture_Variance_Mito_3_0                          0.604192
# Nuclei_Texture_Variance_Mito_5_0                          0.616031
# Nuclei_Texture_Variance_RNA_10_0                          0.407567
#
#                                    Nuclei_Texture_Variance_ER_3_0  \
# Cells_AreaShape_Area                                    -0.416301
# Cells_AreaShape_Center_X                                 0.215896
# Cells_AreaShape_Center_Y                                -0.048388
# Cells_AreaShape_MajorAxisLength                         -0.500746
# Cells_AreaShape_MaxFeretDiameter                        -0.514430
# ...                                                           ...
# Nuclei_Texture_Variance_ER_5_0                           0.990076
# Nuclei_Texture_Variance_Mito_10_0                        0.654662
# Nuclei_Texture_Variance_Mito_3_0                         0.717252
# Nuclei_Texture_Variance_Mito_5_0                         0.720942
# Nuclei_Texture_Variance_RNA_10_0                         0.408610
#
#                                    Nuclei_Texture_Variance_ER_5_0  \
# Cells_AreaShape_Area                                    -0.410450
# Cells_AreaShape_Center_X                                 0.220046
# Cells_AreaShape_Center_Y                                -0.049593
# Cells_AreaShape_MajorAxisLength                         -0.493739
# Cells_AreaShape_MaxFeretDiameter                        -0.507519
# ...                                                           ...
# Nuclei_Texture_Variance_ER_5_0                           1.000000
# Nuclei_Texture_Variance_Mito_10_0                        0.660725
# Nuclei_Texture_Variance_Mito_3_0                         0.705781
# Nuclei_Texture_Variance_Mito_5_0                         0.712087
# Nuclei_Texture_Variance_RNA_10_0                         0.405825
#
#                                    Nuclei_Texture_Variance_Mito_10_0  \
# Cells_AreaShape_Area                                       -0.402776
# Cells_AreaShape_Center_X                                    0.180561
# Cells_AreaShape_Center_Y                                   -0.044146
# Cells_AreaShape_MajorAxisLength                            -0.509588
# Cells_AreaShape_MaxFeretDiameter                           -0.518317
# ...                                                              ...
# Nuclei_Texture_Variance_ER_5_0                              0.660725
# Nuclei_Texture_Variance_Mito_10_0                           1.000000
# Nuclei_Texture_Variance_Mito_3_0                            0.913445
# Nuclei_Texture_Variance_Mito_5_0                            0.927219
# Nuclei_Texture_Variance_RNA_10_0                            0.500762
#
#                                    Nuclei_Texture_Variance_Mito_3_0  \
# Cells_AreaShape_Area                                      -0.466908
# Cells_AreaShape_Center_X                                   0.203888
# Cells_AreaShape_Center_Y                                  -0.027690
# Cells_AreaShape_MajorAxisLength                           -0.577228
# Cells_AreaShape_MaxFeretDiameter                          -0.585288
# ...                                                             ...
# Nuclei_Texture_Variance_ER_5_0                             0.705781
# Nuclei_Texture_Variance_Mito_10_0                          0.913445
# Nuclei_Texture_Variance_Mito_3_0                           1.000000
# Nuclei_Texture_Variance_Mito_5_0                           0.991749
# Nuclei_Texture_Variance_RNA_10_0                           0.452315
#
#                                    Nuclei_Texture_Variance_Mito_5_0  \
# Cells_AreaShape_Area                                      -0.465243
# Cells_AreaShape_Center_X                                   0.203251
# Cells_AreaShape_Center_Y                                  -0.022484
# Cells_AreaShape_MajorAxisLength                           -0.574887
# Cells_AreaShape_MaxFeretDiameter                          -0.583702
# ...                                                             ...
# Nuclei_Texture_Variance_ER_5_0                             0.712087
# Nuclei_Texture_Variance_Mito_10_0                          0.927219
# Nuclei_Texture_Variance_Mito_3_0                           0.991749
# Nuclei_Texture_Variance_Mito_5_0                           1.000000
# Nuclei_Texture_Variance_RNA_10_0                           0.453696
#
#                                    Nuclei_Texture_Variance_RNA_10_0
# Cells_AreaShape_Area                                      -0.190705
# Cells_AreaShape_Center_X                                   0.083418
# Cells_AreaShape_Center_Y                                  -0.075793
# Cells_AreaShape_MajorAxisLength                           -0.255735
# Cells_AreaShape_MaxFeretDiameter                          -0.261028
# ...                                                             ...
# Nuclei_Texture_Variance_ER_5_0                             0.405825
# Nuclei_Texture_Variance_Mito_10_0                          0.500762
# Nuclei_Texture_Variance_Mito_3_0                           0.452315
# Nuclei_Texture_Variance_Mito_5_0                           0.453696
# Nuclei_Texture_Variance_RNA_10_0                           1.000000
#
# [715 rows x 715 columns]

# %%
pairwise_df
# Out:
#                                   pair_a                             pair_b  \
# 0               Cells_AreaShape_Center_X               Cells_AreaShape_Area
# 1               Cells_AreaShape_Center_Y               Cells_AreaShape_Area
# 2               Cells_AreaShape_Center_Y           Cells_AreaShape_Center_X
# 3        Cells_AreaShape_MajorAxisLength               Cells_AreaShape_Area
# 4        Cells_AreaShape_MajorAxisLength           Cells_AreaShape_Center_X
# ...                                  ...                                ...
# 255250  Nuclei_Texture_Variance_RNA_10_0     Nuclei_Texture_Variance_ER_3_0
# 255251  Nuclei_Texture_Variance_RNA_10_0     Nuclei_Texture_Variance_ER_5_0
# 255252  Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_Mito_10_0
# 255253  Nuclei_Texture_Variance_RNA_10_0   Nuclei_Texture_Variance_Mito_3_0
# 255254  Nuclei_Texture_Variance_RNA_10_0   Nuclei_Texture_Variance_Mito_5_0
#
#         correlation
# 0         -0.098339
# 1         -0.030454
# 2          0.006942
# 3          0.940841
# 4         -0.113692
# ...             ...
# 255250     0.408610
# 255251     0.405825
# 255252     0.500762
# 255253     0.452315
# 255254     0.453696
#
# [255255 rows x 3 columns]

# %%
def determine_high_cor_pair(correlation_row, sorted_correlation_pairs):
    """
    Select highest correlated variable given a correlation row with columns:
    ["pair_a", "pair_b", "correlation"]
    For use in a pandas.apply()
    """

    pair_a = correlation_row["pair_a"]
    pair_b = correlation_row["pair_b"]

    if sorted_correlation_pairs.get_loc(pair_a) > sorted_correlation_pairs.get_loc(pair_b):
        return pair_a
    else:
        return pair_b

# %%
# Get absolute sum of correlation across features
# The lower the index, the less correlation to the full data frame
# We want to drop features with highest correlation, so drop higher index
variable_cor_sum = data_cor_df.abs().sum().sort_values().index

# And subset to only variable combinations that pass the threshold
pairwise_df = pairwise_df.query("correlation > 0.9")

# Return an empty list if nothing is over correlation threshold
print(pairwise_df.shape[0])
      
excluded = pairwise_df.apply(lambda x: determine_high_cor_pair(x, variable_cor_sum), axis="columns")
excluded_features = list(set(excluded.tolist()))
# Out:
# 2674

# %%
len(excluded_features)
# Out:
# 486

# %%
new_CP_pubchem_data_2 = new_CP_pubchem_data.drop(excluded_features, axis=1)
new_CP_pubchem_data_2
# Out:
#        Cells_AreaShape_Orientation  Cells_AreaShape_Perimeter  \
# 0                         2.304579                   2.762969
# 1                         3.128759                   2.845656
# 2                         0.787541                   4.970742
# 3                        -0.704484                  13.992016
# 4                         1.116134                   7.755992
# ...                            ...                        ...
# 10397                     0.120879                 -19.894852
# 10398                     1.923609                   2.942820
# 10399                     1.573557                  -7.385164
# 10400                    -3.767544                  21.085742
# 10401                    -4.308093                  -8.465930
#
#        Cells_Correlation_Correlation_DNA_AGP  \
# 0                                  -0.045399
# 1                                   0.129807
# 2                                   0.021885
# 3                                   0.047799
# 4                                   0.026384
# ...                                      ...
# 10397                              -0.009067
# 10398                              -0.020739
# 10399                              -0.002143
# 10400                               0.351428
# 10401                               0.034543
#
#        Cells_Correlation_Correlation_ER_AGP  Cells_Correlation_K_AGP_DNA  \
# 0                                 -0.052834                    -0.006567
# 1                                  0.068373                    -0.033614
# 2                                  0.023282                     0.035352
# 3                                  0.027258                    -0.000531
# 4                                  0.012069                    -0.038810
# ...                                     ...                          ...
# 10397                              0.028331                    -0.073881
# 10398                             -0.017560                    -0.022186
# 10399                              0.009537                     0.002578
# 10400                              0.342367                     0.239651
# 10401                              0.051980                     0.002810
#
#        Cells_Correlation_K_DNA_AGP  Cells_Correlation_K_DNA_ER  \
# 0                         0.011172                    0.009235
# 1                         0.071465                    0.076745
# 2                        -0.056394                   -0.055012
# 3                        -0.029938                   -0.047386
# 4                         0.064665                    0.072837
# ...                            ...                         ...
# 10397                     0.061545                    0.072425
# 10398                    -0.004646                   -0.003457
# 10399                    -0.008484                   -0.022082
# 10400                    -0.065820                   -0.026131
# 10401                     0.005369                   -0.024415
#
#        Cells_Correlation_K_DNA_Mito  Cells_Correlation_K_ER_DNA  \
# 0                         -0.013632                   -0.012062
# 1                          0.156491                   -0.040814
# 2                         -0.060501                    0.024850
# 3                         -0.004365                    0.010389
# 4                          0.039043                   -0.038961
# ...                             ...                         ...
# 10397                      0.080479                   -0.029669
# 10398                      0.042389                    0.005012
# 10399                      0.008640                   -0.002887
# 10400                      0.124606                    0.039575
# 10401                      0.010092                    0.014883
#
#        Cells_Correlation_K_ER_Mito  ...  Nuclei_Texture_SumVariance_AGP_10_0  \
# 0                        -0.012975  ...                            -0.074715
# 1                         0.077470  ...                            -0.085634
# 2                        -0.000387  ...                             0.002818
# 3                         0.017189  ...                            -0.204273
# 4                        -0.011498  ...                            -0.218014
# ...                            ...  ...                                  ...
# 10397                     0.038259  ...                             0.016725
# 10398                     0.052370  ...                            -0.098627
# 10399                     0.025904  ...                            -0.003622
# 10400                     0.142086  ...                            -0.212069
# 10401                     0.024787  ...                             0.040701
#
#        Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                                -0.042175
# 1                                -0.174593
# 2                                 0.298685
# 3                                -0.219672
# 4                                -0.106546
# ...                                    ...
# 10397                             0.172473
# 10398                            -0.064359
# 10399                            -0.255099
# 10400                            -0.168908
# 10401                             0.121044
#
#        Nuclei_Texture_SumVariance_ER_10_0  \
# 0                               -0.126538
# 1                               -0.174820
# 2                               -0.034911
# 3                               -0.183920
# 4                               -0.114580
# ...                                   ...
# 10397                            0.109905
# 10398                           -0.059644
# 10399                           -0.049035
# 10400                            0.570236
# 10401                            0.105409
#
#        Nuclei_Texture_SumVariance_Mito_10_0  \
# 0                                 -0.135921
# 1                                  0.067516
# 2                                 -0.311239
# 3                                 -0.057310
# 4                                 -0.331848
# ...                                     ...
# 10397                             -0.281850
# 10398                             -0.276168
# 10399                             -0.111082
# 10400                             -0.251480
# 10401                             -0.135182
#
#        Nuclei_Texture_SumVariance_RNA_10_0  \
# 0                                -0.218352
# 1                                 0.017844
# 2                                -0.173322
# 3                                -0.032487
# 4                                -0.072634
# ...                                    ...
# 10397                            -0.086699
# 10398                            -0.168500
# 10399                            -0.148793
# 10400                            -0.552330
# 10401                             0.055974
#
#        Nuclei_Texture_SumVariance_RNA_5_0  Nuclei_Texture_Variance_AGP_10_0  \
# 0                               -0.348235                          0.022734
# 1                               -0.137245                          0.006468
# 2                               -0.328665                          0.031219
# 3                               -0.227981                         -0.115135
# 4                               -0.193127                         -0.059346
# ...                                   ...                               ...
# 10397                           -0.249878                          0.028272
# 10398                           -0.332086                         -0.020784
# 10399                           -0.180716                          0.013233
# 10400                           -0.725024                         -0.234750
# 10401                            0.067851                          0.056524
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                            -0.064442                          -0.049853
# 1                            -0.029972                           0.017667
# 2                             0.020276                          -0.050662
# 3                            -0.108891                          -0.022526
# 4                             0.013632                          -0.157595
# ...                                ...                                ...
# 10397                         0.077785                          -0.046787
# 10398                        -0.040793                          -0.123188
# 10399                         0.003183                          -0.033117
# 10400                         0.463339                           0.091231
# 10401                         0.167289                           0.021183
#
#        Nuclei_Texture_Variance_RNA_10_0
# 0                             -0.037229
# 1                              0.070510
# 2                             -0.056293
# 3                             -0.030227
# 4                              0.010668
# ...                                 ...
# 10397                         -0.064416
# 10398                          0.009448
# 10399                         -0.020764
# 10400                         -0.263527
# 10401                          0.011932
#
# [10402 rows x 229 columns]

# %%
max_feature_values = new_CP_pubchem_data_2.max().abs()
min_feature_values = new_CP_pubchem_data_2.min().abs()

outlier_features = max_feature_values[(max_feature_values > 15) | (min_feature_values > 15)].index.tolist()

# %%
new_CP_pubchem_data_3 = new_CP_pubchem_data_2.drop(outlier_features, axis=1)
new_CP_pubchem_data_3
# Out:
#        Cells_Correlation_Correlation_DNA_AGP  \
# 0                                  -0.045399
# 1                                   0.129807
# 2                                   0.021885
# 3                                   0.047799
# 4                                   0.026384
# ...                                      ...
# 10397                              -0.009067
# 10398                              -0.020739
# 10399                              -0.002143
# 10400                               0.351428
# 10401                               0.034543
#
#        Cells_Correlation_Correlation_ER_AGP  Cells_Correlation_K_AGP_DNA  \
# 0                                 -0.052834                    -0.006567
# 1                                  0.068373                    -0.033614
# 2                                  0.023282                     0.035352
# 3                                  0.027258                    -0.000531
# 4                                  0.012069                    -0.038810
# ...                                     ...                          ...
# 10397                              0.028331                    -0.073881
# 10398                             -0.017560                    -0.022186
# 10399                              0.009537                     0.002578
# 10400                              0.342367                     0.239651
# 10401                              0.051980                     0.002810
#
#        Cells_Correlation_K_DNA_AGP  Cells_Correlation_K_DNA_ER  \
# 0                         0.011172                    0.009235
# 1                         0.071465                    0.076745
# 2                        -0.056394                   -0.055012
# 3                        -0.029938                   -0.047386
# 4                         0.064665                    0.072837
# ...                            ...                         ...
# 10397                     0.061545                    0.072425
# 10398                    -0.004646                   -0.003457
# 10399                    -0.008484                   -0.022082
# 10400                    -0.065820                   -0.026131
# 10401                     0.005369                   -0.024415
#
#        Cells_Correlation_K_DNA_Mito  Cells_Correlation_K_ER_DNA  \
# 0                         -0.013632                   -0.012062
# 1                          0.156491                   -0.040814
# 2                         -0.060501                    0.024850
# 3                         -0.004365                    0.010389
# 4                          0.039043                   -0.038961
# ...                             ...                         ...
# 10397                      0.080479                   -0.029669
# 10398                      0.042389                    0.005012
# 10399                      0.008640                   -0.002887
# 10400                      0.124606                    0.039575
# 10401                      0.010092                    0.014883
#
#        Cells_Correlation_K_ER_Mito  Cells_Correlation_K_Mito_DNA  \
# 0                        -0.012975                     -0.010769
# 1                         0.077470                     -0.102940
# 2                        -0.000387                      0.045720
# 3                         0.017189                     -0.008475
# 4                        -0.011498                     -0.063074
# ...                            ...                           ...
# 10397                     0.038259                     -0.087029
# 10398                     0.052370                     -0.063380
# 10399                     0.025904                     -0.015267
# 10400                     0.142086                     -0.061881
# 10401                     0.024787                     -0.007616
#
#        Cells_Correlation_K_RNA_DNA  ...  Nuclei_Texture_SumVariance_AGP_10_0  \
# 0                        -0.016556  ...                            -0.074715
# 1                        -0.031626  ...                            -0.085634
# 2                         0.039360  ...                             0.002818
# 3                         0.063592  ...                            -0.204273
# 4                        -0.049690  ...                            -0.218014
# ...                            ...  ...                                  ...
# 10397                    -0.124156  ...                             0.016725
# 10398                    -0.014991  ...                            -0.098627
# 10399                    -0.013379  ...                            -0.003622
# 10400                     0.139468  ...                            -0.212069
# 10401                    -0.013146  ...                             0.040701
#
#        Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                                -0.042175
# 1                                -0.174593
# 2                                 0.298685
# 3                                -0.219672
# 4                                -0.106546
# ...                                    ...
# 10397                             0.172473
# 10398                            -0.064359
# 10399                            -0.255099
# 10400                            -0.168908
# 10401                             0.121044
#
#        Nuclei_Texture_SumVariance_ER_10_0  \
# 0                               -0.126538
# 1                               -0.174820
# 2                               -0.034911
# 3                               -0.183920
# 4                               -0.114580
# ...                                   ...
# 10397                            0.109905
# 10398                           -0.059644
# 10399                           -0.049035
# 10400                            0.570236
# 10401                            0.105409
#
#        Nuclei_Texture_SumVariance_Mito_10_0  \
# 0                                 -0.135921
# 1                                  0.067516
# 2                                 -0.311239
# 3                                 -0.057310
# 4                                 -0.331848
# ...                                     ...
# 10397                             -0.281850
# 10398                             -0.276168
# 10399                             -0.111082
# 10400                             -0.251480
# 10401                             -0.135182
#
#        Nuclei_Texture_SumVariance_RNA_10_0  \
# 0                                -0.218352
# 1                                 0.017844
# 2                                -0.173322
# 3                                -0.032487
# 4                                -0.072634
# ...                                    ...
# 10397                            -0.086699
# 10398                            -0.168500
# 10399                            -0.148793
# 10400                            -0.552330
# 10401                             0.055974
#
#        Nuclei_Texture_SumVariance_RNA_5_0  Nuclei_Texture_Variance_AGP_10_0  \
# 0                               -0.348235                          0.022734
# 1                               -0.137245                          0.006468
# 2                               -0.328665                          0.031219
# 3                               -0.227981                         -0.115135
# 4                               -0.193127                         -0.059346
# ...                                   ...                               ...
# 10397                           -0.249878                          0.028272
# 10398                           -0.332086                         -0.020784
# 10399                           -0.180716                          0.013233
# 10400                           -0.725024                         -0.234750
# 10401                            0.067851                          0.056524
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                            -0.064442                          -0.049853
# 1                            -0.029972                           0.017667
# 2                             0.020276                          -0.050662
# 3                            -0.108891                          -0.022526
# 4                             0.013632                          -0.157595
# ...                                ...                                ...
# 10397                         0.077785                          -0.046787
# 10398                        -0.040793                          -0.123188
# 10399                         0.003183                          -0.033117
# 10400                         0.463339                           0.091231
# 10401                         0.167289                           0.021183
#
#        Nuclei_Texture_Variance_RNA_10_0
# 0                             -0.037229
# 1                              0.070510
# 2                             -0.056293
# 3                             -0.030227
# 4                              0.010668
# ...                                 ...
# 10397                         -0.064416
# 10398                          0.009448
# 10399                         -0.020764
# 10400                         -0.263527
# 10401                          0.011932
#
# [10402 rows x 184 columns]

# %%
new_CP_pubchem_data_3["StdInChI"]= CP_pubchem_data["StdInChI"]
new_CP_pubchem_data_3
# Out:
#        Cells_Correlation_Correlation_DNA_AGP  \
# 0                                  -0.045399
# 1                                   0.129807
# 2                                   0.021885
# 3                                   0.047799
# 4                                   0.026384
# ...                                      ...
# 10397                              -0.009067
# 10398                              -0.020739
# 10399                              -0.002143
# 10400                               0.351428
# 10401                               0.034543
#
#        Cells_Correlation_Correlation_ER_AGP  Cells_Correlation_K_AGP_DNA  \
# 0                                 -0.052834                    -0.006567
# 1                                  0.068373                    -0.033614
# 2                                  0.023282                     0.035352
# 3                                  0.027258                    -0.000531
# 4                                  0.012069                    -0.038810
# ...                                     ...                          ...
# 10397                              0.028331                    -0.073881
# 10398                             -0.017560                    -0.022186
# 10399                              0.009537                     0.002578
# 10400                              0.342367                     0.239651
# 10401                              0.051980                     0.002810
#
#        Cells_Correlation_K_DNA_AGP  Cells_Correlation_K_DNA_ER  \
# 0                         0.011172                    0.009235
# 1                         0.071465                    0.076745
# 2                        -0.056394                   -0.055012
# 3                        -0.029938                   -0.047386
# 4                         0.064665                    0.072837
# ...                            ...                         ...
# 10397                     0.061545                    0.072425
# 10398                    -0.004646                   -0.003457
# 10399                    -0.008484                   -0.022082
# 10400                    -0.065820                   -0.026131
# 10401                     0.005369                   -0.024415
#
#        Cells_Correlation_K_DNA_Mito  Cells_Correlation_K_ER_DNA  \
# 0                         -0.013632                   -0.012062
# 1                          0.156491                   -0.040814
# 2                         -0.060501                    0.024850
# 3                         -0.004365                    0.010389
# 4                          0.039043                   -0.038961
# ...                             ...                         ...
# 10397                      0.080479                   -0.029669
# 10398                      0.042389                    0.005012
# 10399                      0.008640                   -0.002887
# 10400                      0.124606                    0.039575
# 10401                      0.010092                    0.014883
#
#        Cells_Correlation_K_ER_Mito  Cells_Correlation_K_Mito_DNA  \
# 0                        -0.012975                     -0.010769
# 1                         0.077470                     -0.102940
# 2                        -0.000387                      0.045720
# 3                         0.017189                     -0.008475
# 4                        -0.011498                     -0.063074
# ...                            ...                           ...
# 10397                     0.038259                     -0.087029
# 10398                     0.052370                     -0.063380
# 10399                     0.025904                     -0.015267
# 10400                     0.142086                     -0.061881
# 10401                     0.024787                     -0.007616
#
#        Cells_Correlation_K_RNA_DNA  ...  Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                        -0.016556  ...                            -0.042175
# 1                        -0.031626  ...                            -0.174593
# 2                         0.039360  ...                             0.298685
# 3                         0.063592  ...                            -0.219672
# 4                        -0.049690  ...                            -0.106546
# ...                            ...  ...                                  ...
# 10397                    -0.124156  ...                             0.172473
# 10398                    -0.014991  ...                            -0.064359
# 10399                    -0.013379  ...                            -0.255099
# 10400                     0.139468  ...                            -0.168908
# 10401                    -0.013146  ...                             0.121044
#
#        Nuclei_Texture_SumVariance_ER_10_0  \
# 0                               -0.126538
# 1                               -0.174820
# 2                               -0.034911
# 3                               -0.183920
# 4                               -0.114580
# ...                                   ...
# 10397                            0.109905
# 10398                           -0.059644
# 10399                           -0.049035
# 10400                            0.570236
# 10401                            0.105409
#
#        Nuclei_Texture_SumVariance_Mito_10_0  \
# 0                                 -0.135921
# 1                                  0.067516
# 2                                 -0.311239
# 3                                 -0.057310
# 4                                 -0.331848
# ...                                     ...
# 10397                             -0.281850
# 10398                             -0.276168
# 10399                             -0.111082
# 10400                             -0.251480
# 10401                             -0.135182
#
#        Nuclei_Texture_SumVariance_RNA_10_0  \
# 0                                -0.218352
# 1                                 0.017844
# 2                                -0.173322
# 3                                -0.032487
# 4                                -0.072634
# ...                                    ...
# 10397                            -0.086699
# 10398                            -0.168500
# 10399                            -0.148793
# 10400                            -0.552330
# 10401                             0.055974
#
#        Nuclei_Texture_SumVariance_RNA_5_0  Nuclei_Texture_Variance_AGP_10_0  \
# 0                               -0.348235                          0.022734
# 1                               -0.137245                          0.006468
# 2                               -0.328665                          0.031219
# 3                               -0.227981                         -0.115135
# 4                               -0.193127                         -0.059346
# ...                                   ...                               ...
# 10397                           -0.249878                          0.028272
# 10398                           -0.332086                         -0.020784
# 10399                           -0.180716                          0.013233
# 10400                           -0.725024                         -0.234750
# 10401                            0.067851                          0.056524
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                            -0.064442                          -0.049853
# 1                            -0.029972                           0.017667
# 2                             0.020276                          -0.050662
# 3                            -0.108891                          -0.022526
# 4                             0.013632                          -0.157595
# ...                                ...                                ...
# 10397                         0.077785                          -0.046787
# 10398                        -0.040793                          -0.123188
# 10399                         0.003183                          -0.033117
# 10400                         0.463339                           0.091231
# 10401                         0.167289                           0.021183
#
#        Nuclei_Texture_Variance_RNA_10_0  \
# 0                             -0.037229
# 1                              0.070510
# 2                             -0.056293
# 3                             -0.030227
# 4                              0.010668
# ...                                 ...
# 10397                         -0.064416
# 10398                          0.009448
# 10399                         -0.020764
# 10400                         -0.263527
# 10401                          0.011932
#
#                                                 StdInChI
# 0      InChI=1S/C11H14ClN3O4S3/c1-2-3-20-6-11-14-8-4-...
# 1      InChI=1S/C25H27ClN2O/c26-22-12-7-13-23(18-22)2...
# 2      InChI=1S/C18H20O2/c1-18-9-8-14-13-5-3-12(19)10...
# 3      InChI=1S/C16H13ClN2O/c1-19-14-8-7-12(17)9-13(1...
# 4      InChI=1S/C10H14ClN3/c11-9-2-1-3-10(13-9)14-6-4...
# ...                                                  ...
# 10397  InChI=1S/C34H41N5O3S/c1-34(2,3)43(42)39-23-28-...
# 10398  InChI=1S/C34H36N4O3S/c1-34(2,3)42(41)38-22-28-...
# 10399  InChI=1S/C33H39N5O3S/c1-33(2,3)42(41)38-22-27-...
# 10400  InChI=1S/C27H26ClFN2O6S/c28-17-3-1-16(2-4-17)1...
# 10401  InChI=1S/C26H31N3O7/c1-29(2)12-25(32)28-16-4-6...
#
# [10402 rows x 185 columns]

# %%
new_CP_pubchem_data_3.to_csv("CP_filtered_10402.csv", index=False)
