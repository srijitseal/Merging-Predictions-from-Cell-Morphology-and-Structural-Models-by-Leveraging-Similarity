# %%
#This notebook combines all metrics and heirarchial
import pandas as pd

# %%
all_preds_test_compounds_m= pd.read_csv("Predictions_train_heldout_scaled_prob_all_assays_ensemble_merger_test_compounds.csv")
all_preds_test_compounds_h= pd.read_csv("Predictions_train_heldout_scaled_prob_all_assays_heirarchial_model_test_compounds.csv")

# %%
metrics_list_m = pd.read_csv("All_metrics.csv")
metrics_list_h = pd.read_csv("heirarchial_model_metrics.csv")

# %%
all_preds_test_compounds = pd.merge(all_preds_test_compounds_m,all_preds_test_compounds_h)
all_preds_test_compounds= all_preds_test_compounds.sort_values("assay").reset_index(drop=True)
all_preds_test_compounds
# Out:
#            assay                                           StdInChI  fp_proba  \
# 0        1117304  InChI=1S/C27H36ClFO5/c1-14-9-16-17-11-19(29)18...  0.227629
# 1        1117304  InChI=1S/C15H12N2O3S/c1-20-11-6-8-12(9-7-11)21...  0.384489
# 2        1117304  InChI=1S/C9H6O3/c10-7-3-1-6-2-4-9(11)12-8(6)5-...  0.371232
# 3        1117304  InChI=1S/C12H17N5/c1-8-6-4-5-7-9(8)14-11-15-10...  0.298134
# 4        1117304  InChI=1S/C6H8ClN7O/c7-2-4(9)13-3(8)1(12-2)5(15...  0.242485
# ...          ...                                                ...       ...
# 10123  Novartis2  InChI=1S/C14H13Cl2NO3/c1-9-5-10(15)6-12(16)14(...  0.441790
# 10124  Novartis2  InChI=1S/C19H18O8/c1-8-5-13(26-4)11(7-20)17(22...  0.382330
# 10125  Novartis2  InChI=1S/C12H13N3O2/c1-17-12(16)10-7-4-2-3-5-9...  0.274487
# 10126  Novartis2  InChI=1S/C16H14N2OS/c1-18-9-8-17-16(18)20-11-1...  0.261270
# 10127  Novartis2  InChI=1S/C17H19N5O3/c23-17(19-16-3-1-2-8-18-16...  0.394976
#
#        fp_pred  fp_threshold  CP_proba  CP_pred  CP_threshold  true        ts  \
# 0            0      0.342959  0.415502        1      0.366563   0.0  0.500000
# 1            1      0.342959  0.285488        0      0.366563   1.0  0.290323
# 2            1      0.342959  0.283642        0      0.366563   1.0  0.466667
# 3            0      0.342959  0.283255        0      0.366563   0.0  0.300000
# 4            0      0.342959  0.362674        0      0.366563   0.0  0.285714
# ...        ...           ...       ...      ...           ...   ...       ...
# 10123        1      0.258317  0.567265        1      0.520819   0.0  0.378378
# 10124        1      0.258317  0.587759        1      0.520819   0.0  0.379310
# 10125        1      0.258317  0.518695        0      0.520819   0.0  0.270270
# 10126        1      0.258317  0.407709        0      0.520819   0.0  0.352941
# 10127        1      0.258317  0.412755        0      0.520819   1.0  0.295455
#
#        ...  MFP_Correct CP_Correct  fp_proba_scaled  CP_proba_scaled  \
# 0      ...         True      False         0.331860         0.538630
# 1      ...         True      False         0.531604         0.389412
# 2      ...         True      False         0.521515         0.386894
# 3      ...         True       True         0.434650         0.386366
# 4      ...         True       True         0.353519         0.494695
# ...    ...          ...        ...              ...              ...
# 10123  ...        False      False         0.623687         0.548465
# 10124  ...        False      False         0.583603         0.569849
# 10125  ...        False       True         0.510901         0.497961
# 10126  ...        False       True         0.501991         0.391412
# 10127  ...         True      False         0.592128         0.396256
#
#        simple_pred  Ensemble_Correct  merger_pred  merger_Correct  \
# 0              0.0              True          0.0            True
# 1              0.0             False          1.0            True
# 2              0.0             False          1.0            True
# 3              0.0              True          1.0           False
# 4              0.0              True          1.0           False
# ...            ...               ...          ...             ...
# 10123          1.0             False          1.0           False
# 10124          1.0             False          1.0           False
# 10125          1.0             False          1.0           False
# 10126          0.0              True          1.0           False
# 10127          0.0             False          1.0            True
#
#        heirarchial_pred  heirarchial_Correct
# 0                   0.0                 True
# 1                   1.0                 True
# 2                   1.0                 True
# 3                   0.0                 True
# 4                   0.0                 True
# ...                 ...                  ...
# 10123               0.0                 True
# 10124               0.0                 True
# 10125               0.0                 True
# 10126               0.0                 True
# 10127               0.0                False
#
# [10128 rows x 22 columns]

# %%
metrics_list = pd.concat([metrics_list_m,metrics_list_h])
metrics_list = metrics_list.sort_values(["assay", "method"]).reset_index(drop=True)
metrics_list
# Out:
#          assay                 method        f1  precision  Sensitivity  \
# 0      1117304                     CP  0.320000   0.320000     0.320000
# 1      1117304  Distance Based Merger  0.588235   0.465116     0.800000
# 2      1117304      Ensemble Averaged  0.260870   0.285714     0.240000
# 3      1117304      Heirarchial Model  0.454545   0.365854     0.600000
# 4      1117304                    MFP  0.508475   0.441176     0.600000
# ..         ...                    ...       ...        ...          ...
# 455  Novartis2                     CP  0.125000   0.142857     0.111111
# 456  Novartis2  Distance Based Merger  0.461538   0.352941     0.666667
# 457  Novartis2      Ensemble Averaged  0.347826   0.285714     0.444444
# 458  Novartis2      Heirarchial Model  0.000000   0.000000     0.000000
# 459  Novartis2                    MFP  0.484848   0.333333     0.888889
#
#      Specificity        ba       mcc       AUC
# 0       0.679245  0.499623 -0.000755  0.445283
# 1       0.566038  0.683019  0.343452  0.664906
# 2       0.716981  0.478491 -0.045261  0.478491
# 3       0.509434  0.554717  0.102274  0.535094
# 4       0.641509  0.620755  0.227288  0.532075
# ..           ...       ...       ...       ...
# 455     0.647059  0.379085 -0.259376  0.379085
# 456     0.352941  0.509804  0.019608  0.535948
# 457     0.411765  0.428105 -0.137222  0.428105
# 458     1.000000  0.500000  0.000000  0.535948
# 459     0.058824  0.473856 -0.093352  0.470588
#
# [460 rows x 9 columns]

# %%
metrics_list.to_csv("All_metrics_merger_heirarchial.csv", index=False)

# %%
all_preds_test_compounds.to_csv("Predictions_train_heldout_scaled_prob_all_assays_ensemble_merger_heirarchial_test_compounds.csv", index=False)
